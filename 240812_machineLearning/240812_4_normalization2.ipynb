# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

data = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]


scaler.fit(data)
# Out:
# MinMaxScaler()

# %%
import pandas as pd
import math 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
scaler.data_max_
# Out:
# array([ 1., 18.])

# %%
scaler.transform(data)
# Out:
# array([[0.  , 0.  ],
#        [0.25, 0.25],
#        [0.5 , 0.5 ],
#        [1.  , 1.  ]])

# %%
scaler.transform([[2,2]])
# Out:
# array([[1.5, 0. ]])

# %%
mpg_df = pd.read_csv("C:/shjung/pythonExam/240812_machineLearning/autompg_copy.csv", encoding="cp949")
mpg_df.horsepower.replace('?', np.nan, inplace=True)
mpg_df.horsepower.unique()
mpg_df.horsepower = mpg_df.horsepower.astype('float')
mpg_df.horsepower.dtype
mpg_df.dropna(subset=['horsepower'], axis=0, inplace=True)
count, bin_dividers = np.histogram(mpg_df['horsepower'], bins=3)
bin_names= ['저출력', '보통출력', '고출력'] 
mpg_df['hp_bin'] = pd.cut(x=mpg_df['horsepower'], bins=bin_dividers, labels=bin_names, include_lowest=True) 
pd.get_dummies(mpg_df['hp_bin'])
mpg_df.horsepower.dtype
# Out:
# C:\Users\shjung\AppData\Local\Temp\ipykernel_10380\1337106359.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mpg_df.horsepower.replace('?', np.nan, inplace=True)
# dtype('float64')

# %%
scaler.fit(mpg_df.horsepower.values.reshape(392, -1))
# scaler.fit(mpg_df.horsepower.values)
# Out:
# MinMaxScaler()

# %%
result = scaler.transform(mpg_df.horsepower.values.reshape(392, -1))

# %%
result.describe()
# Out:
# array([[0.45652174],
#        [0.64673913],
#        [0.56521739],
#        [0.56521739],
#        [0.51086957],
#        [0.82608696],
#        [0.94565217],
#        [0.91847826],
#        [0.97282609],
#        [0.7826087 ],
#        [0.67391304],
#        [0.61956522],
#        [0.56521739],
#        [0.97282609],
#        [0.26630435],
#        [0.26630435],
#        [0.27717391],
#        [0.21195652],
#        [0.22826087],
#        [0.        ],
#        [0.22282609],
#        [0.23913043],
#        [0.26630435],
#        [0.36413043],
#        [0.23913043],
#        [0.91847826],
#        [0.83695652],
#        [0.89130435],
#        [0.79891304],
#        [0.22826087],
#        [0.23913043],
#        [0.26630435],
#        [0.29347826],
#        [0.32065217],
#        [0.29347826],
#        [0.22826087],
#        [0.29347826],
#        [0.64673913],
#        [0.70108696],
#        [0.58152174],
#        [0.56521739],
#        [0.72826087],
#        [0.67391304],
#        [0.70108696],
#        [0.34782609],
#        [0.14130435],
#        [0.29347826],
#        [0.22826087],
#        [0.2173913 ],
#        [0.23913043],
#        [0.13043478],
#        [0.16304348],
#        [0.10326087],
#        [0.125     ],
#        [0.07608696],
#        [0.13043478],
#        [0.26630435],
#        [0.18478261],
#        [0.04347826],
#        [0.23913043],
#        [0.2173913 ],
#        [0.64673913],
#        [0.70108696],
#        [0.56521739],
#        [0.58152174],
#        [0.56521739],
#        [0.88043478],
#        [0.5923913 ],
#        [0.61956522],
#        [0.7826087 ],
#        [0.27717391],
#        [0.56521739],
#        [0.45652174],
#        [0.51086957],
#        [0.56521739],
#        [0.35869565],
#        [0.16304348],
#        [0.22282609],
#        [0.125     ],
#        [0.2173913 ],
#        [0.25      ],
#        [0.27717391],
#        [0.18478261],
#        [0.22826087],
#        [0.70108696],
#        [0.56521739],
#        [0.53804348],
#        [0.49456522],
#        [0.56521739],
#        [0.82608696],
#        [0.56521739],
#        [0.60869565],
#        [0.56521739],
#        [0.91847826],
#        [0.97282609],
#        [0.70108696],
#        [0.32065217],
#        [0.29347826],
#        [0.29347826],
#        [0.22826087],
#        [0.26630435],
#        [0.        ],
#        [0.56521739],
#        [0.6576087 ],
#        [0.67391304],
#        [0.72826087],
#        [0.29347826],
#        [0.22826087],
#        [0.14130435],
#        [0.26086957],
#        [0.23913043],
#        [0.21195652],
#        [0.33152174],
#        [0.23913043],
#        [0.53804348],
#        [1.        ],
#        [0.01630435],
#        [0.1576087 ],
#        [0.24456522],
#        [0.35869565],
#        [0.56521739],
#        [0.34782609],
#        [0.41304348],
#        [0.72826087],
#        [0.26630435],
#        [0.29347826],
#        [0.29347826],
#        [0.11413043],
#        [0.18478261],
#        [0.10326087],
#        [0.1576087 ],
#        [0.29347826],
#        [0.34782609],
#        [0.32065217],
#        [0.51086957],
#        [0.56521739],
#        [0.56521739],
#        [0.51086957],
#        [0.56521739],
#        [0.20108696],
#        [0.11413043],
#        [0.17391304],
#        [0.0326087 ],
#        [0.08152174],
#        [0.1576087 ],
#        [0.1576087 ],
#        [0.1576087 ],
#        [0.27717391],
#        [0.25543478],
#        [0.11413043],
#        [0.26630435],
#        [0.32065217],
#        [0.14130435],
#        [0.14130435],
#        [0.67391304],
#        [0.53804348],
#        [0.56521739],
#        [0.55434783],
#        [0.34782609],
#        [0.32065217],
#        [0.34782609],
#        [0.26630435],
#        [0.34782609],
#        [0.34782609],
#        [0.45108696],
#        [0.1576087 ],
#        [0.20108696],
#        [0.29347826],
#        [0.17391304],
#        [0.27173913],
#        [0.13586957],
#        [0.27717391],
#        [0.27717391],
#        [0.13043478],
#        [0.23913043],
#        [0.26630435],
#        [0.22826087],
#        [0.2826087 ],
#        [0.375     ],
#        [0.03804348],
#        [0.2173913 ],
#        [0.19021739],
#        [0.25      ],
#        [0.17934783],
#        [0.20108696],
#        [0.51086957],
#        [0.56521739],
#        [0.40217391],
#        [0.57608696],
#        [0.29347826],
#        [0.32065217],
#        [0.19021739],
#        [0.23913043],
#        [0.0326087 ],
#        [0.07608696],
#        [0.13043478],
#        [0.03804348],
#        [0.29347826],
#        [0.17391304],
#        [0.34782609],
#        [0.26630435],
#        [0.13586957],
#        [0.13043478],
#        [0.1576087 ],
#        [0.14130435],
#        [0.30434783],
#        [0.56521739],
#        [0.22826087],
#        [0.33695652],
#        [0.40217391],
#        [0.72826087],
#        [0.53804348],
#        [0.45652174],
#        [0.56521739],
#        [0.11956522],
#        [0.18478261],
#        [0.06521739],
#        [0.27173913],
#        [0.13043478],
#        [0.53804348],
#        [0.34782609],
#        [0.53804348],
#        [0.45652174],
#        [0.34782609],
#        [0.32065217],
#        [0.29347826],
#        [0.2826087 ],
#        [0.72826087],
#        [0.67391304],
#        [0.7826087 ],
#        [0.55978261],
#        [0.17391304],
#        [0.22826087],
#        [0.1576087 ],
#        [0.23369565],
#        [0.0923913 ],
#        [0.20108696],
#        [0.11413043],
#        [0.17391304],
#        [0.27717391],
#        [0.34782609],
#        [0.34782609],
#        [0.01086957],
#        [0.10869565],
#        [0.0326087 ],
#        [0.13043478],
#        [0.07608696],
#        [0.34782609],
#        [0.51086957],
#        [0.50543478],
#        [0.32065217],
#        [0.26630435],
#        [0.21195652],
#        [0.22826087],
#        [0.29347826],
#        [0.23913043],
#        [0.32065217],
#        [0.21195652],
#        [0.34782609],
#        [0.40217391],
#        [0.53804348],
#        [0.64673913],
#        [0.50543478],
#        [0.51086957],
#        [0.11956522],
#        [0.26630435],
#        [0.27717391],
#        [0.1576087 ],
#        [0.26630435],
#        [0.32065217],
#        [0.21195652],
#        [0.27717391],
#        [0.30978261],
#        [0.42934783],
#        [0.375     ],
#        [0.47282609],
#        [0.13586957],
#        [0.11956522],
#        [0.375     ],
#        [0.21195652],
#        [0.22826087],
#        [0.23913043],
#        [0.34782609],
#        [0.45652174],
#        [0.45108696],
#        [0.5       ],
#        [0.48369565],
#        [0.5923913 ],
#        [0.52173913],
#        [0.42934783],
#        [0.56521739],
#        [0.13586957],
#        [0.10326087],
#        [0.18478261],
#        [0.18478261],
#        [0.16847826],
#        [0.42934783],
#        [0.13586957],
#        [0.23913043],
#        [0.13043478],
#        [0.13043478],
#        [0.10326087],
#        [0.125     ],
#        [0.23913043],
#        [0.375     ],
#        [0.375     ],
#        [0.23913043],
#        [0.16304348],
#        [0.07608696],
#        [0.13043478],
#        [0.10326087],
#        [0.23913043],
#        [0.22826087],
#        [0.23913043],
#        [0.23913043],
#        [0.17391304],
#        [0.23913043],
#        [0.1576087 ],
#        [0.25      ],
#        [0.1576087 ],
#        [0.10326087],
#        [0.32065217],
#        [0.10326087],
#        [0.01086957],
#        [0.01086957],
#        [0.11413043],
#        [0.11413043],
#        [0.11413043],
#        [0.11413043],
#        [0.08695652],
#        [0.4673913 ],
#        [0.29347826],
#        [0.22826087],
#        [0.14130435],
#        [0.20652174],
#        [0.20652174],
#        [0.25      ],
#        [0.34782609],
#        [0.20652174],
#        [0.06521739],
#        [0.09782609],
#        [0.07608696],
#        [0.11413043],
#        [0.10326087],
#        [0.08695652],
#        [0.11956522],
#        [0.0923913 ],
#        [0.10326087],
#        [0.10326087],
#        [0.15217391],
#        [0.1576087 ],
#        [0.1576087 ],
#        [0.29347826],
#        [0.15217391],
#        [0.18478261],
#        [0.16304348],
#        [0.38043478],
#        [0.40217391],
#        [0.34782609],
#        [0.32065217],
#        [0.22826087],
#        [0.21195652],
#        [0.22826087],
#        [0.22826087],
#        [0.22826087],
#        [0.21195652],
#        [0.20652174],
#        [0.23913043],
#        [0.25      ],
#        [0.15217391],
#        [0.11956522],
#        [0.11956522],
#        [0.0923913 ],
#        [0.13043478],
#        [0.22826087],
#        [0.1576087 ],
#        [0.13043478],
#        [0.11413043],
#        [0.11413043],
#        [0.11413043],
#        [0.34782609],
#        [0.21195652],
#        [0.25      ],
#        [0.35869565],
#        [0.27173913],
#        [0.20652174],
#        [0.23913043],
#        [0.2173913 ],
#        [0.0326087 ],
#        [0.20652174],
#        [0.17934783],
#        [0.19565217]])

# %%
scaler.transform([[2,2]])

# %% [markdown]
# ### 2) 표준화 (Z-score normalization)

# %%
data2 = [[166, 55],[168, 40],[170, 80],[172, 93],[174, 77]]

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
std_scaler .fit_transform(data2)
# Out:
# array([[-1.41421356, -0.73827505],
#        [-0.70710678, -1.52928404],
#        [ 0.        ,  0.58007326],
#        [ 0.70710678,  1.26561438],
#        [ 1.41421356,  0.42187146]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 모자이크 그래프
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# contingency table :
#     분할 한다. 만일의 사태, 상황에 따라 분할표

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# data =sns.load_dataset('tips')
# sns.mosaicplot(data=data, index=['sex','smoker'], title='Mosaic Plot of Gender Smoking Status')
# plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statsmodels.graphics.mosaicplot import mosaic
import seaborn as sns

titanic = sns.load_dataset('titanic')

# %%
import matplotlib.pyplot as plt

titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
mosaic(titanic, ['pclass', 'survived'])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 다변량
# scatter plot :
#     두개 상관을 본다. 흩어진 정도
#     선형관계 식별
#
#
#     음의 상관관계, 양의 상관관계
#     패턴을 잘봐야 한다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 다변량 박스 플롯

# %% [markdown]
# 난수 생성 >> 난수표

# %%
np.random.seed()
# 10 으로 시드 테스트

# %%
# 재현율이 안좋다. 10고정
# 난수표를 맞춘다.
# 여러분과 동일한 숫자를 보기 위해, 난수표 동일 숫자로 설정
np.random.seed(10)

# %%
np.random.randint(0, 10)
# Out:
# 9

# %%
np.random.normal()
# Out:
# -0.05126562808663009

# %%
# help(np.random.normal)
# normal(...) method of numpy.random.mtrand.RandomState instance
# normal(loc=0.0, scale=1.0, size=None)

# %%
np.random.normal(0, 1)
# Out:
# -1.9069318981400183

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
