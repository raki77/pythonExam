# %%
# norm : 크기 , 노말라이징 -> 단위벡터 구하기
# norm : 규격, 기준 

import numpy as np
from scipy import linalg
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dict_data = {
    'a': 1,
    'b': 2,
    'c': 3    
}

# %%
pd.Series(['남','여'])
# Out:
# 0    남
# 1    여
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
di = {
    'a' : 'apple',
    'b' : 'banana',
    'c' : 'candy'
}
ser1= pd.Series(di)

# %%
pd.DataFrame(ser1)
# Out:
#         0
# a   apple
# b  banana
# c   candy

# %%
df_fruit = pd.DataFrame(ser1)

# %%
df_fruit.columns = ['fruit']

# %%
df_fruit
# Out:
#     fruit
# a   apple
# b  banana
# c   candy

# %%
df_fruit.columns
# Out:
# Index(['fruit'], dtype='object')

# %%
type(ser1)
# Out:
# pandas.core.series.Series

# %%
# help(df_fruit.rename)

# %%
df_fruit.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df_fruit.columns=['fruit2']

# %%
di2 = {
    'a': 'anaconda',
    'b': 'black_yark',
    'c': 'cat'
}

# %%
# 칼럼추가
df_fruit['animal'] = di2

# %%
df_fruit
# Out:
#    fruit2      animal
# a   apple    anaconda
# b  banana  black_yark
# c   candy         cat

# %%
di3 = {
    'a': 'albatross',
    'b': 'black_eagle',
    'c': 'crane'
}

# %%
df_fruit['bird'] = di3

# %%
df_fruit
# Out:
#    fruit2      animal         bird
# a   apple    anaconda    albatross
# b  banana  black_yark  black_eagle
# c   candy         cat        crane

# %%
df_fruit.loc['c']['animal'] = 'dog'
# Out:
# C:\Users\shjung\AppData\Local\Temp\ipykernel_12724\2224086180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fruit.loc['c']['animal'] = 'dog'

# %%
df_fruit
# Out:
#    fruit2      animal         bird
# a   apple    anaconda    albatross
# b  banana  black_yark  black_eagle
# c   candy         dog        crane

# %%
# 나이가 27인 사람의 도시를 'San Francisco'로 변경
# df.loc[df['age'] == 27, 'city'] = 'San Francisco'

df_fruit.iloc[2,1] = 'dog'

# %%
df_fruit.drop('animal', axis = 1, inplace=True)

# %%
df_fruit
# Out:
#    fruit2         bird
# a   apple    albatross
# b  banana  black_eagle
# c   candy        crane

# %%
df_fruit.drop('b', axis = 0 , inplace=True)

# %%
df_fruit
# Out:
#   fruit2       bird
# a  apple  albatross
# c  candy      crane

# %% [markdown]
# ![image.png](attachment:image.png)
