# %%
# norm : 크기 , 노말라이징 -> 단위벡터 구하기
# norm : 규격, 기준 

import numpy as np
from scipy import linalg

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 데이타 불러오기

# %%
import pandas as pd
# cp949 : excel 관련된 형식 ms만듬
# utf8, utf-8
df_stu1 = pd.read_csv('C:/shjung/pythonExam/240807_linalg_pandas2/student.csv', encoding="cp949")
df_stu1
# Out:
#    id  학생명    키  몸무게  나이 성별
# 0   1  홍일동  166   59  19  남
# 1   2  홍이동  168  600  19  여
# 2   3  홍삼동  170   33  19  남
# 3   4  홍사동  172   32  19  여
# 4   5  홍오동  174   30  19  남

# %%
type(df_stu1)
# Out:
# pandas.core.frame.DataFrame

# %%
# DataFrame : 칼럼별로 쪼갤 수 있다.
df_stu1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5 non-null      int64
#  1   학생명     5 non-null      object
#  2   키       5 non-null      int64
#  3   몸무게     5 non-null      int64
#  4   나이      5 non-null      int64
#  5   성별      5 non-null      object
# dtypes: int64(4), object(2)
# memory usage: 372.0+ bytes

# %%
# 헤더 잡기
df_stu1.columns
# Out:
# Index(['id', '학생명', '키', '몸무게', '나이', '성별'], dtype='object')

# %%
df_stu1.id
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: id, dtype: int64

# %%
df_stu1.학생명
# Out:
# 0    홍일동
# 1    홍이동
# 2    홍삼동
# 3    홍사동
# 4    홍오동
# Name: 학생명, dtype: object

# %%
type(df_stu1['몸무게'])
# Out:
# pandas.core.series.Series

# %%
# Series : 인덱스가 있는 배열

# %%
# boxplot의 개념
df_stu1.describe()
# Out:
#              id           키         몸무게    나이
# count  5.000000    5.000000    5.000000   5.0
# mean   3.000000  170.000000  150.800000  19.0
# std    1.581139    3.162278  251.391527   0.0
# min    1.000000  166.000000   30.000000  19.0
# 25%    2.000000  168.000000   32.000000  19.0
# 50%    3.000000  170.000000   33.000000  19.0
# 75%    4.000000  172.000000   59.000000  19.0
# max    5.000000  174.000000  600.000000  19.0

# %%
df_stu1.head(0)
# Out:
# Empty DataFrame
# Columns: [id, 학생명, 키, 몸무게, 나이, 성별]
# Index: []

# %%
# NaN: Not a Number
df_stu1.describe(include='all')
# Out:
#               id  학생명           키         몸무게    나이   성별
# count   5.000000    5    5.000000    5.000000   5.0    5
# unique       NaN    5         NaN         NaN   NaN    2
# top          NaN  홍일동         NaN         NaN   NaN    남
# freq         NaN    1         NaN         NaN   NaN    3
# mean    3.000000  NaN  170.000000  150.800000  19.0  NaN
# std     1.581139  NaN    3.162278  251.391527   0.0  NaN
# min     1.000000  NaN  166.000000   30.000000  19.0  NaN
# 25%     2.000000  NaN  168.000000   32.000000  19.0  NaN
# 50%     3.000000  NaN  170.000000   33.000000  19.0  NaN
# 75%     4.000000  NaN  172.000000   59.000000  19.0  NaN
# max     5.000000  NaN  174.000000  600.000000  19.0  NaN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# DDL(define) :  create
# DML(manipulation:다루다)  : CRUD
# DCL(control): revoke
# not only : ~뿐만 아니라
# NoSql : MongoDB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_stu1['키']
# Out:
# array([166, 168, 170, 172, 174], dtype=int64)

# %%
df_stu1['키'].values
# Out:
# array([166, 168, 170, 172, 174], dtype=int64)

# %%
height = df_stu1['키'].values

# %%
height.var()
# Out:
# 8.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# help(pd.DataFrame())

# %%
stu_dic = {'학생명':['홍일동','홍이동','홍삼동','홍사동','홍오동']}

# %%
type(stu_dic)
# Out:
# dict

# %%
id = {'id':[1,2,3,4,5]}

# %%
# res1 = np.array(['홍일동','홍이동','홍삼동','홍사동','홍오동'])
# res2 = np.array([1,2,3,4,5])

# result = np.append(res1, res2, axis= 0)
# result = result.reshape(2,5)
# np.transpose(result)
# np.transpose(result, (1,0,2))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[105], line 6
#       4 result = np.append(res1, res2, axis= 0)
#       5 result = result.reshape(2,5)
# ----> 6 np.transpose(result,(1,2))
#
# File c:\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:655, in transpose(a, axes)
#     588 @array_function_dispatch(_transpose_dispatcher)
#     589 def transpose(a, axes=None):
#     590     """
#     591     Returns an array with axes transposed.
#     592
#    (...)
#     653
#     654     """
# --> 655     return _wrapfunc(a, 'transpose', axes)
#
# File c:\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
# ...

# %%
res1= np.array([
[ 1,'홍일동',166,59,19 ,'남'],
[ 2,'홍이동',168,600,19,'여'],
[ 3,'홍삼동',170,33,19 ,'남'],
[ 4,'홍사동',172,32,19 ,'여'],
[ 5,'홍오동',174,30,19 ,'남']])

# %%
pd.DataFrame(data=res1, columns=['id','학생명','키','몸무게','나이','성별'])
# Out:
#   id  학생명    키  몸무게  나이 성별
# 0  1  홍일동  166   59  19  남
# 1  2  홍이동  168  600  19  여
# 2  3  홍삼동  170   33  19  남
# 3  4  홍사동  172   32  19  여
# 4  5  홍오동  174   30  19  남

# %%
stu_df = pd.DataFrame(data=res1, columns=['id','학생명','키','몸무게','나이','성별'])

# %%
stu_df
# Out:
#   id  학생명    키  몸무게  나이 성별
# 0  1  홍일동  166   59  19  남
# 1  2  홍이동  168  600  19  여
# 2  3  홍삼동  170   33  19  남
# 3  4  홍사동  172   32  19  여
# 4  5  홍오동  174   30  19  남

# %%
stu_df.columns
# Out:
# Index(['id', '학생명', '키', '몸무게', '나이', '성별'], dtype='object')

# %%
stu_df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# help(stu_df.set_index)

# %%
# inplace=True : 즉시 수정 적용해라
stu_df.set_index('id', inplace=True)

# %%
stu_df
# Out:
#     학생명    키  몸무게  나이 성별
# id
# 1   홍일동  166   59  19  남
# 2   홍이동  168  600  19  여
# 3   홍삼동  170   33  19  남
# 4   홍사동  172   32  19  여
# 5   홍오동  174   30  19  남

# %%
# index 값으로 찾는다.
stu_df.iloc[0]
# Out:
# 학생명    홍일동
# 키      166
# 몸무게     59
# 나이      19
# 성별       남
# Name: 1, dtype: object

# %%
# 앞에 있는 키값 가지고 한다.
stu_df.loc['1']
# Out:
# 학생명    홍일동
# 키      166
# 몸무게     59
# 나이      19
# 성별       남
# Name: 1, dtype: object

# %%
stu_df['성별']
# Out:
# id
# 1    남
# 2    여
# 3    남
# 4    여
# 5    남
# Name: 성별, dtype: object

# %%
stu_df['키']
# Out:
# id
# 1    166
# 2    168
# 3    170
# 4    172
# 5    174
# Name: 키, dtype: object

# %%
stu_df[( stu_df['키'].astype(int) >= 170) & (stu_df['성별'] == '남')]
# Out:
#     학생명    키 몸무게  나이 성별
# id
# 3   홍삼동  170  33  19  남
# 5   홍오동  174  30  19  남

# %%
(stu_df['몸무게'].astype(int) >= 170)
# Out:
# id
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# Name: 몸무게, dtype: bool

# %%
stu_df['몸무게'].dtype
# Out:
# dtype('O')

# %%
# 1. 키 170이상
stu_df[(stu_df['키'].astype(int) >= 170)]
# Out:
#     학생명    키 몸무게  나이 성별
# id
# 3   홍삼동  170  33  19  남
# 4   홍사동  172  32  19  여
# 5   홍오동  174  30  19  남

# %%
# 2. 몸무게 50 이고, 성별이 '여자'인것
stu_df[(stu_df['몸무게'].astype(int) == 50) & (stu_df['성별'] == '여')]
# Out:
# Empty DataFrame
# Columns: [학생명, 키, 몸무게, 나이, 성별]
# Index: []

# %%
# 3. 키 170미만 and 몸무게 50이상
stu_df[( stu_df['키'].astype(int) < 170) & (stu_df['몸무게'].astype(int) >= 50) ]
# Out:
#     학생명    키  몸무게  나이 성별
# id
# 1   홍일동  166   59  19  남
# 2   홍이동  168  600  19  여

# %%
# 4. 키가 170미만 or 몸무게 50이상
stu_df[( stu_df['키'].astype(int) < 170) | (stu_df['몸무게'].astype(int) >= 50)]
# Out:
#     학생명    키  몸무게  나이 성별
# id
# 1   홍일동  166   59  19  남
# 2   홍이동  168  600  19  여

# %%
stu_df[( stu_df['몸무게'].astype(int) == 600)]
# Out:
#     학생명    키  몸무게  나이 성별
# id
# 2   홍이동  168  600  19  여

# %%
stu_df.iloc[1,2]
# Out:
# '600'

# %%
stu_df.loc['2']['몸무게']
# Out:
# '600'

# %%
stu_df.loc['2'][['몸무게','나이']]
# Out:
# 몸무게    600
# 나이      19
# Name: 2, dtype: object

# %%
stu_df.loc[['3','5']][['학생명','몸무게','나이']]
# Out:
#     학생명 몸무게  나이
# id
# 3   홍삼동  33  19
# 5   홍오동  30  19

# %%
stu_df.iloc[[1, 4]]
# Out:
#     학생명    키  몸무게  나이 성별
# id
# 2   홍이동  168  600  19  여
# 5   홍오동  174   30  19  남

# %%
stu_df.loc[['2', '5']]
# Out:
#     학생명    키  몸무게  나이 성별
# id
# 2   홍이동  168  600  19  여
# 5   홍오동  174   30  19  남

# %% [markdown]
# ![image.png](attachment:image.png)
