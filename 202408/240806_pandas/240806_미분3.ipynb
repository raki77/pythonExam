# %%
# 합성함수 (안미분*바깥미분)
import sympy as sp
from sympy import expand, factor, Symbol
# 심볼 x 정의
x = sp.symbols('x')

# %% [markdown]
# $y= x^4$

# %%
val1 = x**4
# 미분 (differentiation)
val2 = sp.diff(val1, x)

# %%
val2
# Out:
# 4*x**3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $함수   y = x^2 - 5x$ 미분하라.

# %%
val3 = sp.diff(x**2, x)

# %%
val3
# Out:
# 2*x

# %%
val4 = sp.diff(5*x, x)

# %%
val4
# Out:
# 5

# %%
val3-val4
# Out:
# 2*x - 5

# %%
sp.diff(x**2-5*x, x)
# Out:
# 2*x - 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = sp.diff(3*x**2 - 1 ,x)

# %%
res1 = a * (2*(x**2)+ 4*x + 2)

# %%
res1
# Out:
# 6*x*(2*x**2 + 4*x + 2)

# %%
b = sp.diff(2*(x**2) + 4*x +2 , x)

# %%
res2 =  (3*(x**2)-1) * b

# %%
res2
# Out:
# (4*x + 4)*(3*x**2 - 1)

# %%
expand(res1+res2)
# Out:
# 24*x**3 + 36*x**2 + 8*x - 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $ y = \frac{2x^2 + 3x}{x^2 + 1} $ 미분하라

# %%
val1 = 2*x**2 + 3*x
val2 = x**2 +1
res1 = sp.diff(val1, x)*val2 - val1* sp.diff(val2, x)

# %%
res1
# Out:
# -2*x*(2*x**2 + 3*x) + (4*x + 3)*(x**2 + 1)

# %%
res2 = val2**2

# %%
res2
# Out:
# (x**2 + 1)**2

# %%
res1/res2
# Out:
# (-2*x*(2*x**2 + 3*x) + (4*x + 3)*(x**2 + 1))/(x**2 + 1)**2

# %%
val4 = -2*x * (2*x**2 + 3*x)
val5 = (4*x+3) * (x**2+1)

# %%
sp.expand(val4 + val5)
# Out:
# -3*x**2 + 4*x + 3

# %%
sp.expand(val4 + val5) / res2
# Out:
# (-3*x**2 + 4*x + 3)/(x**2 + 1)**2

# %%
# 미분 가능하다??
