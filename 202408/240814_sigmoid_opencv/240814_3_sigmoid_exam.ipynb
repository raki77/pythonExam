# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

def softplus(x):
    return np.log(1 + np.exp(x))


# 예제
x = np.linspace(-10, 10, 100)
y1 = sigmoid(x)
y2 = relu(x)
y3 = tanh(x)
y4 = softplus(x)

plt.title('Functions')
plt.subplot(2,2,1)
plt.plot(x, y1, color='r')
plt.ylim(0, 1)
plt.legend(['sigmoid'], loc='upper right')

plt.subplot(2,2,2)
plt.plot(x, y2, color='b')  
plt.legend(['relu'], loc='upper right')

plt.subplot(2,2,3)
plt.plot(x, y3, color='g')
plt.legend(['tanh'], loc='upper right')

plt.subplot(2,2,4)
plt.plot(x, y4, color='y') 
plt.legend(['softplus'], loc='upper right')
plt.show()

# %%
def softplus(x):
    return np.log(1 + np.exp(x))

# 예제
x = np.linspace(-10, 10, 100)
y = softplus(x)

plt.plot(x, y)
plt.title('Softplus Function')
plt.xlabel('x')
plt.ylabel('Softplus(x)')
plt.grid(True)
plt.show()

# %%
def tanh(x):
    return np.tanh(x)

# 예제
x = np.linspace(-10, 10, 100)
y = tanh(x)

plt.plot(x, y)
plt.title('Hyperbolic Tangent Function')
plt.xlabel('x')
plt.ylabel('tanh(x)')
plt.grid(True)
plt.show()

# %%
def relu(x):
    return np.maximum(0, x)

# 예제
x = np.linspace(-10, 10, 100)
y = relu(x)

plt.plot(x, y)
plt.title('ReLU Function')
plt.xlabel('x')
plt.ylabel('ReLU(x)')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# 예제
x = np.linspace(-10, 10, 100)
y = sigmoid(x)

plt.plot(x, y)
plt.title('Sigmoid Function')
plt.xlabel('x')
plt.ylabel('sigmoid(x)')
plt.grid(True)
plt.show()
