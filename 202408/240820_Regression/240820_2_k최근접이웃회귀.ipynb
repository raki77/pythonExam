# %% [markdown]
# ## 결정 계수 ($R^2$)

# %%
from sklearn.neighbors import KNeighborsRegressor
import numpy as np

# %%
knr = KNeighborsRegressor()

# %%
knr
# Out:
# KNeighborsRegressor()

# %%
perch_length = np.array(
    [8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0,
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5,
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5,
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0,
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0,
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0]
     )
perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0,
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0,
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0,
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0,
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0,
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0,
     1000.0, 1000.0]
     )

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(perch_length, perch_weight)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
np.corrcoef(perch_length, perch_weight)
# Out:
# array([[1.        , 0.95865587],
#        [0.95865587, 1.        ]])

# %%
(0.95865587)**2
# Out:
# 0.9190210770854569

# %%
from sklearn.model_selection import train_test_split

# %%
len(perch_length)
# Out:
# 56

# %%
56*0.75 , 56* 0.25
# Out:
# (42.0, 14.0)

# %%
X_train , X_test, y_train, y_test = train_test_split(perch_length, perch_weight, 
                                                    random_state=42,
                                                    test_size=0.25, 
                                                    shuffle=True)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (42,)
# (14,)
# (42,)
# (14,)

# %%
# 현재 1차원
X_train.ndim
# Out:
# 1

# %%
# help(knr.fit)
# {array-like, sparse matrix} : 희소행렬, 0이 대부분 차지 하는것, 2차원

# %%
 # 2차원으로 변경
X_train2 = X_train.reshape(-1,1)
X_train2
# Out:
# array([[19.6],
#        [22. ],
#        [18.7],
#        [17.4],
#        [36. ],
#        [25. ],
#        [40. ],
#        [39. ],
#        [43. ],
#        [22. ],
#        [20. ],
#        [22. ],
#        [24. ],
#        [27.5],
#        [43. ],
#        [40. ],
#        [24. ],
#        [21. ],
#        [27.5],
#        [40. ],
#        [32.8],
#        [26.5],
#        [36.5],
#        [13.7],
#        [22.7],
#        [15. ],
#        [37. ],
#        [35. ],
#        [28.7],
#        [23.5],
#        [39. ],
#        [21. ],
#        [23. ],
#        [22. ],
#        [44. ],
#        [22.5],
#        [19. ],
#        [37. ],
#        [22. ],
#        [25.6],
#        [42. ],
#        [34.5]])

# %%
knr.fit( X_train2, y_train )
# Out:
# KNeighborsRegressor()

# %%
knr.kneighbors()
# Out:
# (array([[0.4, 0.6, 0.9, 1.4, 1.4],
#         [0. , 0. , 0. , 0. , 0.5],
#         [0.3, 0.9, 1.3, 1.3, 2.3],
#         [1.3, 1.6, 2.2, 2.4, 2.6],
#         [0.5, 1. , 1. , 1. , 1.5],
#         [0.6, 1. , 1. , 1.5, 1.5],
#         [0. , 0. , 1. , 1. , 2. ],
#         [0. , 1. , 1. , 1. , 2. ],
#         [0. , 1. , 1. , 3. , 3. ],
#         [0. , 0. , 0. , 0. , 0.5],
#         [0.4, 1. , 1. , 1. , 1.3],
#         [0. , 0. , 0. , 0. , 0.5],
#         [0. , 0.5, 1. , 1. , 1.3],
#         [0. , 1. , 1.2, 1.9, 2.5],
#         [0. , 1. , 1. , 3. , 3. ],
#         [0. , 0. , 1. , 1. , 2. ],
#         [0. , 0.5, 1. , 1. , 1.3],
#         [0. , 1. , 1. , 1. , 1. ],
#         [0. , 1. , 1.2, 1.9, 2.5],
#         [0. , 0. , 1. , 1. , 2. ],
#         [1.7, 2.2, 3.2, 3.7, 4.1],
#         [0.9, 1. , 1. , 1.5, 2.2],
#         [0.5, 0.5, 0.5, 1.5, 2. ],
#         [1.3, 3.7, 5. , 5.3, 5.9],
#         [0.2, 0.3, 0.7, 0.7, 0.7],
#         [1.3, 2.4, 3.7, 4. , 4.6],
#         [0. , 0.5, 1. , 2. , 2. ],
# ...

# %%
# knr.score()

help(knr.score)
# Out:
# Help on method score in module sklearn.base:
#
# score(X, y, sample_weight=None) method of sklearn.neighbors._regression.KNeighborsRegressor instance
#     Return the coefficient of determination of the prediction.
#
#     The coefficient of determination :math:`R^2` is defined as
#     :math:`(1 - \frac{u}{v})`, where :math:`u` is the residual
#     sum of squares ``((y_true - y_pred)** 2).sum()`` and :math:`v`
#     is the total sum of squares ``((y_true - y_true.mean()) ** 2).sum()``.
#     The best possible score is 1.0 and it can be negative (because the
#     model can be arbitrarily worse). A constant model that always predicts
#     the expected value of `y`, disregarding the input features, would get
#     a :math:`R^2` score of 0.0.
#
#     Parameters
#     ----------
#     X : array-like of shape (n_samples, n_features)
#         Test samples. For some estimators this may be a precomputed
#         kernel matrix or a list of generic objects instead with shape
# ...

# %%
X_test2d = X_test.reshape(-1,1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
knr3 = KNeighborsRegressor(n_neighbors=3)
knr7 = KNeighborsRegressor(n_neighbors=7)

# %%
knr3.fit(X_train2, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knr3.score(X_train2, y_train)
# Out:
# 0.9804899950518966

# %%
knr.score(X_train2, y_train) # 훈련세트 평가 (과소적합, 과적합 여부)
# Out:
# 0.9698823289099254

# %%
del knr7

# %%
knr7 = KNeighborsRegressor(n_neighbors=7)

# %%
knr7.fit(X_train2, y_train)
knr7.score(X_train2, y_train)
# Out:
# 0.9761170732051527

# %%
knr.score(X_test2d, y_test)
# Out:
# 0.992809406101064

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 나중에는 하이퍼 파라미터, 그리드서치로 한다.

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 테스트 세트에 대한 예측을 만듭니다
test_prediction = knr.predict(X_test2d)
print(f"test_prediction = {test_prediction}")




# 테스트 세트에 대한 평균 절댓값 오차를 계산합니다
mae = mean_absolute_error(y_test, test_prediction)
print(f"mae = {mae}")
# Out:
# test_prediction = [  60.    79.6  248.   122.   136.   847.   311.4  183.4  847.   113.
#  1010.    60.   248.   248. ]
# mae = 19.157142857142862

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#문제2
knr10 = KNeighborsRegressor()
x = np.arange(5, 45).reshape(-1,1)

for n in [1,5,10]:
    knr10.n_neighbors = n
    knr10.fit(X_train2, y_train)
    prediction = knr10.predict(x)
    # 훈련 세트와 예측 결과 그래프 그리기
    plt.scatter(X_train2, y_train)
    plt.plot(x, prediction)
    plt.title('n_neighbors = {}'.format(n))
    plt.xlabel('length')
    plt.ylabel('weight')
    plt.show()

# %%
knr10.n_neighbors
# Out:
# 10
