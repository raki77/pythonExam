# %%
# 연산자 operator : + - * / 
# 산수
# 논리 

# 명제 : 참과 거짓인지? 문장을 만듬
bool(0) # False
# 비었다는 개념
bool("") # False
bool([]) # False
bool(()) # False
bool({}) # False


bool(1) # True
bool(11) # True
bool(123) # True
# 0을 제외한 나머지는 참이다.
# Out:
# True

# %%
import time
time.sleep(3)
print("hi")
# Out:
# hi

# %%
# CPU : 산술 (Arithmetic), 논리 (Logical), 제어 (control Unit)  --- ALU
# 클래스명 앞글자 : 대문자.
import keyword
keyword.kwlist   # .은 접근하다는 의미이다.
# ['False', 'None:비어있다.', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 
#  'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 
#  'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 
#  'raise','return', 'try', 'while', 'with', 'yield']

# keyword는 라이브러리.

# %%
# 클래스는 '틀'이자 '단위', 타입이다.
print(type(4))

# math.e = 자연상수, # 2.71
# 자연상수 주로 AI개발에 자주 사용.
import math

# '틀'에서 빠져 나온 놈
print(math.e , " : " , math.pi)
# Out:
# <class 'int'>
# 2.718281828459045  :  3.141592653589793

# %%
print("h1")
print()
print("h2")
"h1"
# 파이썬은 기본적으로 찍고 줄 바꿔라.

print(1,2,3)
help(print)
help(input)
# Out:
# h1
#
# h2
# 1 2 3
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.
#
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
# Ascii Code
# New line feed, carriage return 10 - 13
# carriage : 1. (기차의) 객차, 2. 마차, 3. 운반[수송], 운반비[수송비]
# CRLF : 지가 줄바꾸는 방식
# \n : new line
# LF: line feed

# 다음 단어 중 식별자로 사용할 수 있는 것에 O, 사용할 수 없는 것에 X표 하세요.
# a             (     0     )
# hello         (     0     )
# $hello        (     x     )
# 10_hello      (     x     )
# bye           (     0     )

# %%
print("aa\"a\"aa")
print('친구가 "안녕"이라고 말함')
print("친구가 \"안녕\"이라고 말함")

print("친구가 ","안녕","이라고 말함", sep="\"") 
print()
print("친구가 '안녕'이라고 말함")
print('친구가 \'안녕\'이라고 말함')
print("친구가 ","안녕","이라고 말함", sep="\'")
# Out:
# aa"a"aa
# 친구가 "안녕"이라고 말함
# 친구가 "안녕"이라고 말함
# 친구가 "안녕"이라고 말함
#
# 친구가 '안녕'이라고 말함
# 친구가 '안녕'이라고 말함
# 친구가 '안녕'이라고 말함

# %%
# 안녕
# 밥먹자
print("안녕\n밥먹자")

print("""
안녕
밥먹자
""")

print('''
안녕
밥먹자
''')
# Out:
# 안녕
# 밥먹자
#
# 안녕
# 밥먹자
# adfasdfas
# fdas
# fdas
# fdas
#
#
#
#
# 안녕
# 밥먹자

# %%
print("밥\t먹자") 
print("안녕\밥먹자")
print("안녕\\밥먹자")  # \ 2개 타이핑해도 1개 출력된다.
print("\\\\\\\\")
# Out:
# 밥	먹자
# 안녕\밥먹자
# 안녕\밥먹자
# \\\\
# 안녕 밥먹자
# 안녕밥먹자

# %%
# seperator : 구분자 (delimeter)
# concatenate : (문자열) 연결하다.
print("안녕","밥먹자")
print("안녕"+"밥먹자")

# cast 연산
print(1 + int("4"))
# Out:
# 안녕 밥먹자
# 안녕밥먹자
# 5

# %%
menu = input()
print(type(menu))
print(int(menu) + 1)
# Out:
# <class 'str'>
# 5

# %%
menu2 = int(input())
menu2 + 1
# Out:
# 5

# %%
# "hello"[]
# index : 순서,목차,색인

# 검색/ 알고리즘
# 어떻게? 찾는다?
# 순서대로 나열 시켜서,

greeting = "hello"
print(id("hello"[0]))
print(id("hello"[1]))

# 컴퓨터에서는 인덱싱 개념은 [] 대괄호이다.
print(greeting[0]) 
#print(greeting[5])  #error
greeting[0:4] 
# ll
greeting[2:4] 
# ello
greeting[2:6]
greeting[1:]
greeting[:4]
greeting[:]

print(len(greeting))
# Out:
# 140731158376488
# 140731158529832
# h
# 5

# %%
"글자"
'글자'
"""문자열
문자열
문자열"""

'\"'
'\''
'\n'
'\t'
'\\'

# 결과 : # 연습문제
print("# 연습문제") 
# \\\\
print("\\\\\\\\")
# --------
print("-"*8)
# out of range 0,1,2,3,4 까지의 문자열배열임
print("안녕하세요"[5])
