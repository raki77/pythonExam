# %% [markdown]
# # 2장 함수
# #### 수학에서 함수란??
# #### 변수 1개와 다른 변수 간 관계를 정의한다, [표현, 규칙]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. 함수와 방정식

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 수열

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 기계학습:
#   오차를 줄인다. -> 최적화 -> 목적 함수
#
# 기하학 : 점, 선, 면 얼마큼 이냐?
# 크기를 측정위해, 유클리드 거리라 한다.
#
# 방향 개념 -> 백터, 행렬

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
