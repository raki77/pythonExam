# %%
# ------------------------------------------
#  전일 복습 및 복합 대입 연산자 공부
# ------------------------------------------
# 해당 폴더로 가서 c:\ex\py\ code . 실행
# vscode가 실행 된다.


# "hello"[0]
# "hello"[-1]
# "hello"[-6] # error : IndentationError: unexpected indent

# int(input())
# int(input("숫자를 입력하시오."))

# data 가공해서 정보(information) 변환
# 변수명 = 값
# = : 주소로 해서 찾아간다.

# print('hi', 2)
# num1=1+1
# num1
# num1+1
# num1 = num1 + 1
# num1
# 무조건 = 기준으로 오른쪽 부터 계산하고, 왼쪽의 변수에 저장한다.

# 복합대입 연산자
# num2 = 1
# num2 += 1
# num2
# num2 **= 3
# num2
# = 대입연산자는 무조건 마지막에 계산된다. 주소할당

# num = 1
# num -= 0.25
# num /= 0.15
# num *= 0.5
# num *= 1e-2
# num

# string : 사전적의미 줄, 현악기
# type(str(5))
# str(5)

# int('6')
# float('6')
# type(float('6'))
# int('육')   # ValueError: invalid[유효하지 않는] literal[값] for int() with base 10: '육'
# int("52.273") # ValueError: invalid literal for int() with base 10: '52.273'

# format 
# "hi".upper()    # 문자열 틀에 접근한다.
# 객체 : 이 세상 만물 모든 것.

# 공백제거 : remove blank 
# "HI".lower()
# str1 = " niceto ".strip()
# str1[-1]
# str1
# " niceto ".rstrip()
# " niceto ".lstrip()


# ------------------------------------------
# 2-3 문제풀이 답안 제출
# ------------------------------------------
# 변수이름 = 값
# num = 3
# num += 1
# num -= 1
# num *= 1
# num /= 1
# num %= 1
# num **= 2
# int("1234")
# float("1234")
# str(1234)

# ------------------------------------------
# input
# float
# str_input = input("숫자 입력>")
# num_input = float(str_input)
# print()
# print(num_input, "inch")
# print((num_input*2.54), "cm")

# ------------------------------------------
# input
# float
# num_input
# num_input
# ------------------------------------------

# str_input = input("원의 반지름 입력")
# num_input = float(str_input)
# print()
# print("반지름:" , num_input)
# print("둘레:" , 2* 3.14* num_input)
# print("넓이:" , 3.14* num_input**2)

# ------------------------------------------
# tmp = a
# a = b
# b = tmp

# a = input("<문자열입력>")
# b = input("<문자열입력>")
# print(a, b)
# tmp = a
# a = b
# b = tmp
# print(a, b)
# ------------------------------------------

a = input("<문자열입력>")
b = input("<문자열입력>")
print(a, b)
b,a = a,b   # 튜플, 다중 할당, multiple assignment
print(a, b)
# Out:
# 안녕하세요 아침입니다
# 아침입니다 안녕하세요
