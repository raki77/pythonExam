# %%
import pandas as pd
import math 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1_before = pd.read_csv("C:/shjung/pythonExam/240809_preprocessing_pandas/복용전.csv", encoding="cp949")
df1_after = pd.read_csv("C:/shjung/pythonExam/240809_preprocessing_pandas/복용후.csv", encoding="cp949")

# %%
df1_before.head()
df1_after.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 5
#       1 df1_before.head()
#       2 df1_after.head()
# ----> 5 df1_after[:][1]
#
# ...

# %%
print("max:" ,max(df1_before.values))
print("min:" ,min(df1_before.values))
print("max:" ,max(df1_after.values))
print("min:" ,min(df1_after.values))
# Out:
# max: [83]
# min: [54]
# max: [76]
# min: [50]

# %%
df1_before.values.reshape(1, 100)
df1_after.values.reshape(1, 100)
# Out:
# array([[73, 74, 76, 71, 76, 68, 75, 61, 68, 75, 70, 71, 71, 70, 67, 73,
#         74, 50, 76, 68, 75, 74, 73, 69, 68, 75, 61, 68, 75, 67, 73, 74,
#         50, 71, 76, 68, 75, 61, 68, 75, 70, 71, 71, 70, 67, 73, 74, 50,
#         76, 68, 69, 68, 75, 61, 68, 75, 67, 73, 74, 50, 71, 76, 70, 71,
#         71, 70, 67, 73, 74, 50, 76, 68, 74, 50, 76, 68, 69, 68, 75, 61,
#         68, 75, 70, 67, 73, 74, 50, 76, 76, 70, 71, 71, 70, 67, 61, 68,
#         75, 70, 67, 71]], dtype=int64)

# %%
# 2차원을 1차원으로 변경
df2 = df1_before.values.ravel() 
df2_2 = df1_after.values.ravel()
df2_2
# Out:
# array([73, 74, 76, 71, 76, 68, 75, 61, 68, 75, 70, 71, 71, 70, 67, 73, 74,
#        50, 76, 68, 75, 74, 73, 69, 68, 75, 61, 68, 75, 67, 73, 74, 50, 71,
#        76, 68, 75, 61, 68, 75, 70, 71, 71, 70, 67, 73, 74, 50, 76, 68, 69,
#        68, 75, 61, 68, 75, 67, 73, 74, 50, 71, 76, 70, 71, 71, 70, 67, 73,
#        74, 50, 76, 68, 74, 50, 76, 68, 69, 68, 75, 61, 68, 75, 70, 67, 73,
#        74, 50, 76, 76, 70, 71, 71, 70, 67, 61, 68, 75, 70, 67, 71],
#       dtype=int64)

# %%
np.arange(50, 80, 5)
# Out:
# array([50, 55, 60, 65, 70, 75])

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df2, bins=np.arange(50, 85, 5), kde=True)
sns.histplot(df2_2, bins=np.arange(50, 85, 5),kde=True)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
