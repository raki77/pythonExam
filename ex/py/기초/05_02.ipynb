# %%
# 재귀(recursion) 함수

# %%
def f1():
    print("hi")
    f1()

# %%
f1()
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...

# %%
# 팩토리얼 함수 정의

# %% [markdown]
# ![image.png](attachment:564f17f6-441c-48ca-9811-b5c4d12cd4ef.png)

# %%
def factorial(n):
    if n ==1:
        return 1
    return n*factorial(n-1)

# %%
factorial(2)
# Out:
# 2

# %%
factorial(3)
# Out:
# 6

# %%
# 피보나치 : 첫째 및 둘째 항이 1이며 그 뒤의 모든 항은 바로 앞 두 항의 합인 수열

# %%
def fibonacci(n):
    if n==1:
        return 1
    if n==2:
        return 1
    return fibonacci(n-1)+fibonacci(n-2)

# %%
fibonacci(3)
# Out:
# 1

# %%
# 메모화

# %%
dictionary={
    1:1,
    2:1
}

# %%
def fibonachi(n):
    if n in dictionary:
        return dictionary[n]
    else:
        output =fibonachi(n-1)+fibonachi(n-2)
        dictionary[n]=output
        return output

# %%
3 in dictionary
# Out:
# False

# %%
fibonachi(3)
# Out:
# 1

# %%
# 1 1 2 3 5 8 13

# %%
fibonachi(4)
# Out:
# 3

# %%
fibonachi(6)
# Out:
# 8

# %%
fibonachi(50)
# Out:
# 12586269025
